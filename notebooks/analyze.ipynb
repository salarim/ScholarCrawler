# %%
import pandas as pd

df = pd.read_csv('../data/google_scholar_10000_researchers.csv')
# b = pd.read_csv('../data/google_scholar_1000_researchers_by_year')
# c = pd.read_csv('../data/google_scholar_100_researchers_300_papers.csv')


# df = a.append(b, ignore_index=True).append(c, ignore_index=True)

# %%
df['title'] = df['title'].str.strip()
df = df[df['title']!='']
df.sort_values(by='citation', ascending=False, inplace=True)

# %%
df['title_lower'] = df['title'].apply(lambda x: x.lower())

# %%
df.drop_duplicates(subset=['author', 'title_lower'], inplace=True)
df = df.reset_index(drop=True)

# %%
df['authors'] = df.groupby(['title_lower', 'year'])['author'].transform(lambda x: ', '.join(x))

# %%
df.drop_duplicates(subset=['title_lower', 'authors'], inplace=True)
df = df.reset_index(drop=True)
df.drop(labels=['author', 'title_lower'], axis=1, inplace=True)
df = df[['title', 'authors', 'year', 'citation']]

# %%
df.head(100)
# Out:
#                                                 title  \
# 0           The Nature of Statistical Learning Theory
# 1   Learning internal representations by error-pro...
# 2                                      Random forests
# 3                    elements of statistical learning
# 4   The elements of statistical learning: data min...
# 5   Imagenet classification with deep convolutiona...
# 6                Data mining: concepts and techniques
# 7   Learning representations by back-propagating e...
# 8                 Classification and regression trees
# 9       LIBSVM: A library for support vector machines
# 10                   An introduction to the bootstrap
# 11           Pattern recognition and machine learning
# 12  Data Mining: Practical machine learning tools ...
# 13         Artificial intelligence: a modern approach
# 14                            Support-vector networks
# 15  A fast and elitist multiobjective genetic algo...
# 16  Reinforcement learning: An Introduction, 2nd e...
# 17            Neural networks for pattern recognition
# 18   Regression shrinkage and selection via the lasso
# 19                     Independent Component Analysis
# 20                        Latent dirichlet allocation
# 21  Histograms of oriented gradients for human det...
# 22     The appeal of parallel distributed processing.
# 23             Numerical Optimization, Second Edition
# 24       Deep Residual Learning for Image Recognition
# 25         Adam: A Method for Stochastic Optimization
# 26         Adam: A method for stochastic optimization
# 27  Learning internal representations by error pro...
# 28                Bayesian Data Analysis, 3rd Edition
# 29                        GEANT4—a simulation toolkit
# ..                                                ...
# 70                     Going deeper with convolutions
# 71              An introduction to genetic algorithms
# 72  Cytoscape: a software environment for integrat...
# 73  Planck 2015 results. XIII. Cosmological parame...
# 74  Eigenfaces vs. fisherfaces: Recognition using ...
# 75  Fiji: an open-source platform for biological-i...
# 76  Scale-space and edge detection using anisotrop...
# 77                    Robust real-time face detection
# 78  Cooperative diversity in wireless networks: Ef...
# 79  Distributed representations of words and phras...
# 80  Nonlinear dimensionality reduction by locally ...
# 81  Executive summary: heart disease and stroke st...
# 82  An introduction to variable and feature selection
# 83  Molecular classification of cancer: class disc...
# 84  Algorithm for Clustering Data, chapter Cluster...
# 85                     Algorithms for Clustering Data
# 86                         Review of particle physics
# 87  Dropout: a simple way to prevent neural networ...
# 88  Significance analysis of microarrays applied t...
# 89  Conditional random fields: Probabilistic model...
# 90  A global geometric framework for nonlinear dim...
# 91  TensorFlow: Large-scale machine learning on he...
# 92  The ATLAS experiment at the CERN large hadron ...
# 93  TensorFlow: Large-scale machine learning on he...
# 94  TensorFlow: Large-scale machine learning on he...
# 95  Imagenet: A large-scale hierarchical image dat...
# 96                        Introduction to data mining
# 97                            Ant colony optimization
# 98  Caffe: Convolutional architecture for fast fea...
# 99  Batch normalization: Accelerating deep network...
